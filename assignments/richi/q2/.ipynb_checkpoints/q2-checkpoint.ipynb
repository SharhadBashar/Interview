# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### a) Load and clean the data.

# %%
def clean_data(csv_path, skiprows = 5, usecols = [0, 1, 2, 3, 5]):
    df = pd.read_csv(csv_path, skiprows = skiprows, usecols = usecols)
    df = df.dropna(subset=['Description']).reset_index(drop = True)
    return df

def sales_data(df_div_a, df_div_b, years = ['Act2019', 'Act2020', 'Proj2021']):
    return pd.DataFrame(
        {
            'Division A': df_div_a[df_div_a['Description'] == 'Sales Revenue'][years].values.flatten(),
            'Division B': df_div_b[df_div_b['Description'] == 'Sales Revenue'][years].values.flatten()
        },
        index = years
    )

def expenses_data(df_div_a, df_div_b, year = 'Proj2021', expenses = ['SGA', 'ADV', 'DEP', 'RENT', 'OTHX']):
    return pd.DataFrame(
        {
            'Division A': df_div_a[df_div_a['CODE'].isin(expenses)][year].values.flatten(),
            'Division B': df_div_b[df_div_b['CODE'].isin(expenses)][year].values.flatten()
        },
        index = expenses
    )

df_div_a = clean_data('diva-incstmt.csv')
df_div_b = clean_data('divb-incstmt.csv')

df_sales = sales_data(df_div_a, df_div_b)
df_expenses = expenses_data(df_div_a, df_div_b)

# %%
df_div_a_disp = df_div_a.style.set_caption('Division A')
display(df_div_a_disp)

df_div_b_disp = df_div_b.style.set_caption('Division B')
display(df_div_b_disp)
# Out:
# <style type="text/css">
# </style>
# <table id="T_20f32">
#   <caption>Division A</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_20f32_level0_col0" class="col_heading level0 col0" >CODE</th>
#       <th id="T_20f32_level0_col1" class="col_heading level0 col1" >Description</th>
#       <th id="T_20f32_level0_col2" class="col_heading level0 col2" >Act2019</th>
#       <th id="T_20f32_level0_col3" class="col_heading level0 col3" >Act2020</th>
#       <th id="T_20f32_level0_col4" class="col_heading level0 col4" >Proj2021</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_20f32_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_20f32_row0_col0" class="data row0 col0" >SALE</td>
#       <td id="T_20f32_row0_col1" class="data row0 col1" >Sales Revenue</td>
#       <td id="T_20f32_row0_col2" class="data row0 col2" >43.900000</td>
#       <td id="T_20f32_row0_col3" class="data row0 col3" >40.300000</td>
#       <td id="T_20f32_row0_col4" class="data row0 col4" >50.200000</td>
#     </tr>
#     <tr>
#       <th id="T_20f32_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_20f32_row1_col0" class="data row1 col0" >CGS</td>
#       <td id="T_20f32_row1_col1" class="data row1 col1" >Cost of Goods Sold</td>
#       <td id="T_20f32_row1_col2" class="data row1 col2" >17.500000</td>
#       <td id="T_20f32_row1_col3" class="data row1 col3" >18.000000</td>
#       <td id="T_20f32_row1_col4" class="data row1 col4" >22.600000</td>
#     </tr>
#     <tr>
#       <th id="T_20f32_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_20f32_row2_col0" class="data row2 col0" >PROF</td>
#       <td id="T_20f32_row2_col1" class="data row2 col1" >GROSS PROFIT</td>
#       <td id="T_20f32_row2_col2" class="data row2 col2" >26.400000</td>
#       <td id="T_20f32_row2_col3" class="data row2 col3" >22.300000</td>
#       <td id="T_20f32_row2_col4" class="data row2 col4" >27.600000</td>
#     </tr>
#     <tr>
#       <th id="T_20f32_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_20f32_row3_col0" class="data row3 col0" >SGA</td>
#       <td id="T_20f32_row3_col1" class="data row3 col1" >Selling, General, and Admin</td>
#       <td id="T_20f32_row3_col2" class="data row3 col2" >2.100000</td>
#       <td id="T_20f32_row3_col3" class="data row3 col3" >1.800000</td>
#       <td id="T_20f32_row3_col4" class="data row3 col4" >2.100000</td>
#     </tr>
#     <tr>
#       <th id="T_20f32_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_20f32_row4_col0" class="data row4 col0" >ADV</td>
#       <td id="T_20f32_row4_col1" class="data row4 col1" >Advertising</td>
#       <td id="T_20f32_row4_col2" class="data row4 col2" >1.300000</td>
#       <td id="T_20f32_row4_col3" class="data row4 col3" >1.200000</td>
#       <td id="T_20f32_row4_col4" class="data row4 col4" >1.500000</td>
#     </tr>
#     <tr>
#       <th id="T_20f32_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_20f32_row5_col0" class="data row5 col0" >DEP</td>
#       <td id="T_20f32_row5_col1" class="data row5 col1" >Depreciation</td>
#       <td id="T_20f32_row5_col2" class="data row5 col2" >2.600000</td>
#       <td id="T_20f32_row5_col3" class="data row5 col3" >2.500000</td>
#       <td id="T_20f32_row5_col4" class="data row5 col4" >3.200000</td>
#     </tr>
#     <tr>
#       <th id="T_20f32_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_20f32_row6_col0" class="data row6 col0" >RENT</td>
#       <td id="T_20f32_row6_col1" class="data row6 col1" >Rental Expense</td>
#       <td id="T_20f32_row6_col2" class="data row6 col2" >2.200000</td>
#       <td id="T_20f32_row6_col3" class="data row6 col3" >2.200000</td>
#       <td id="T_20f32_row6_col4" class="data row6 col4" >2.200000</td>
#     </tr>
#     <tr>
#       <th id="T_20f32_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_20f32_row7_col0" class="data row7 col0" >OTHX</td>
#       <td id="T_20f32_row7_col1" class="data row7 col1" >Other Expense</td>
#       <td id="T_20f32_row7_col2" class="data row7 col2" >3.100000</td>
#       <td id="T_20f32_row7_col3" class="data row7 col3" >3.200000</td>
#       <td id="T_20f32_row7_col4" class="data row7 col4" >3.400000</td>
#     </tr>
#     <tr>
#       <th id="T_20f32_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_20f32_row8_col0" class="data row8 col0" >EXP</td>
#       <td id="T_20f32_row8_col1" class="data row8 col1" >TOTAL EXPENSES</td>
#       <td id="T_20f32_row8_col2" class="data row8 col2" >11.300000</td>
#       <td id="T_20f32_row8_col3" class="data row8 col3" >10.900000</td>
#       <td id="T_20f32_row8_col4" class="data row8 col4" >12.400000</td>
#     </tr>
#     <tr>
#       <th id="T_20f32_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_20f32_row9_col0" class="data row9 col0" >EBT</td>
#       <td id="T_20f32_row9_col1" class="data row9 col1" >EARNINGS BEFORE TAXES</td>
#       <td id="T_20f32_row9_col2" class="data row9 col2" >15.100000</td>
#       <td id="T_20f32_row9_col3" class="data row9 col3" >11.400000</td>
#       <td id="T_20f32_row9_col4" class="data row9 col4" >15.200000</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_9fb6c">
#   <caption>Division B</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9fb6c_level0_col0" class="col_heading level0 col0" >CODE</th>
#       <th id="T_9fb6c_level0_col1" class="col_heading level0 col1" >Description</th>
#       <th id="T_9fb6c_level0_col2" class="col_heading level0 col2" >Act2019</th>
#       <th id="T_9fb6c_level0_col3" class="col_heading level0 col3" >Act2020</th>
#       <th id="T_9fb6c_level0_col4" class="col_heading level0 col4" >Proj2021</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9fb6c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9fb6c_row0_col0" class="data row0 col0" >SALE</td>
#       <td id="T_9fb6c_row0_col1" class="data row0 col1" >Sales Revenue</td>
#       <td id="T_9fb6c_row0_col2" class="data row0 col2" >33.900000</td>
#       <td id="T_9fb6c_row0_col3" class="data row0 col3" >30.300000</td>
#       <td id="T_9fb6c_row0_col4" class="data row0 col4" >33.900000</td>
#     </tr>
#     <tr>
#       <th id="T_9fb6c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9fb6c_row1_col0" class="data row1 col0" >CGS</td>
#       <td id="T_9fb6c_row1_col1" class="data row1 col1" >Cost of Goods Sold</td>
#       <td id="T_9fb6c_row1_col2" class="data row1 col2" >17.500000</td>
#       <td id="T_9fb6c_row1_col3" class="data row1 col3" >18.000000</td>
#       <td id="T_9fb6c_row1_col4" class="data row1 col4" >14.300000</td>
#     </tr>
#     <tr>
#       <th id="T_9fb6c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9fb6c_row2_col0" class="data row2 col0" >PROF</td>
#       <td id="T_9fb6c_row2_col1" class="data row2 col1" >GROSS PROFIT</td>
#       <td id="T_9fb6c_row2_col2" class="data row2 col2" >16.400000</td>
#       <td id="T_9fb6c_row2_col3" class="data row2 col3" >12.300000</td>
#       <td id="T_9fb6c_row2_col4" class="data row2 col4" >19.700000</td>
#     </tr>
#     <tr>
#       <th id="T_9fb6c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9fb6c_row3_col0" class="data row3 col0" >SGA</td>
#       <td id="T_9fb6c_row3_col1" class="data row3 col1" >Selling, General, and Admin</td>
#       <td id="T_9fb6c_row3_col2" class="data row3 col2" >2.100000</td>
#       <td id="T_9fb6c_row3_col3" class="data row3 col3" >1.800000</td>
#       <td id="T_9fb6c_row3_col4" class="data row3 col4" >2.100000</td>
#     </tr>
#     <tr>
#       <th id="T_9fb6c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9fb6c_row4_col0" class="data row4 col0" >ADV</td>
#       <td id="T_9fb6c_row4_col1" class="data row4 col1" >Advertising</td>
#       <td id="T_9fb6c_row4_col2" class="data row4 col2" >1.300000</td>
#       <td id="T_9fb6c_row4_col3" class="data row4 col3" >1.200000</td>
#       <td id="T_9fb6c_row4_col4" class="data row4 col4" >4.500000</td>
#     </tr>
#     <tr>
#       <th id="T_9fb6c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9fb6c_row5_col0" class="data row5 col0" >DEP</td>
#       <td id="T_9fb6c_row5_col1" class="data row5 col1" >Depreciation</td>
#       <td id="T_9fb6c_row5_col2" class="data row5 col2" >2.100000</td>
#       <td id="T_9fb6c_row5_col3" class="data row5 col3" >2.000000</td>
#       <td id="T_9fb6c_row5_col4" class="data row5 col4" >3.200000</td>
#     </tr>
#     <tr>
#       <th id="T_9fb6c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9fb6c_row6_col0" class="data row6 col0" >RENT</td>
#       <td id="T_9fb6c_row6_col1" class="data row6 col1" >Rental Expense</td>
#       <td id="T_9fb6c_row6_col2" class="data row6 col2" >1.500000</td>
#       <td id="T_9fb6c_row6_col3" class="data row6 col3" >1.500000</td>
#       <td id="T_9fb6c_row6_col4" class="data row6 col4" >2.200000</td>
#     </tr>
#     <tr>
#       <th id="T_9fb6c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9fb6c_row7_col0" class="data row7 col0" >OTHX</td>
#       <td id="T_9fb6c_row7_col1" class="data row7 col1" >Other Expense</td>
#       <td id="T_9fb6c_row7_col2" class="data row7 col2" >3.000000</td>
#       <td id="T_9fb6c_row7_col3" class="data row7 col3" >3.000000</td>
#       <td id="T_9fb6c_row7_col4" class="data row7 col4" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9fb6c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9fb6c_row8_col0" class="data row8 col0" >EXP</td>
#       <td id="T_9fb6c_row8_col1" class="data row8 col1" >TOTAL EXPENSES</td>
#       <td id="T_9fb6c_row8_col2" class="data row8 col2" >10.000000</td>
#       <td id="T_9fb6c_row8_col3" class="data row8 col3" >9.500000</td>
#       <td id="T_9fb6c_row8_col4" class="data row8 col4" >14.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9fb6c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9fb6c_row9_col0" class="data row9 col0" >EBT</td>
#       <td id="T_9fb6c_row9_col1" class="data row9 col1" >EARNINGS BEFORE TAXES</td>
#       <td id="T_9fb6c_row9_col2" class="data row9 col2" >6.400000</td>
#       <td id="T_9fb6c_row9_col3" class="data row9 col3" >2.800000</td>
#       <td id="T_9fb6c_row9_col4" class="data row9 col4" >5.700000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### b) A stacked bar chart of historical and projected sales over time that includes both divisions sales. The X-axis must be the year.

# %%
df_sales.plot.bar(stacked = True, color = ['blue', 'green'])
plt.title('Historical and Projected Division Sales over time')
plt.xlabel('Year')
plt.ylabel('Sales Revenue')
plt.show()

# %%
years = ['Act2019', 'Act2020', 'Proj2021']
df_sales_a = df_div_a[df_div_a['Description'] == 'Sales Revenue'][years]
df_sales_b = df_div_b[df_div_b['Description'] == 'Sales Revenue'][years]
ax = df_sales_a.T.plot.bar(color = 'blue')
df_sales_b.T.plot.bar(ax = ax, color = 'tab:green')
ax.legend(['Division A', 'Division B'])
plt.title('Historical and Projected Division Sales over time')
plt.xlabel('Year')
plt.ylabel('Sales Revenue')
plt.show()

# %% [markdown]
# ### c) A clustered bar chart of historical and projected sales over time that includes both divisions sales. The X-axis must be the year.

# %%
df_sales.plot.bar(color = ['blue', 'green'])
plt.title('Division Sales over time')
plt.xlabel('Year')
plt.ylabel('Sales Revenue')
plt.show()

# %% [markdown]
# ### d) Two seperate pie charts, one for each division, showing the different kinds of expenses forecasted for 2021.

# %%
df_expenses.plot(kind = 'pie', 
                 subplots = True, 
                 figsize = (16, 8), 
                 title = 'Forecasted 2021 Expenses of each divion',
                 autopct = '%1.1f%%'
                )
plt.show()

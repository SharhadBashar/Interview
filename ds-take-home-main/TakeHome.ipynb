# %% [markdown]
# # HealthRhythms Data Science Take Home
#
# Please see `README.md` for more information.
#
# First we load and do some light preprocessing to the data to help you get started. See the [MHEALTH Dataset page](https://archive.ics.uci.edu/ml/datasets/MHEALTH+Dataset) for more information about the dataset.

# %%
from util import load_zipped_csv_dir

# %%
columns = [
    # Chest accelerometer sensor
    'chest_accel_x',
    'chest_accel_y',
    'chest_accel_z',
    
    # ECG (2 leads)
    'ecg_1',
    'ecg_2',
    
    # Left ankle sensors
    'left_accel_x',
    'left_accel_y',
    'left_accel_z',
    'left_gyro_x',
    'left_gyro_y',
    'left_gyro_z',
    'left_mag_x',
    'left_mag_y',
    'left_mag_z',
    
    # Right lower arm sensors
    'right_accel_x',
    'right_accel_y',
    'right_accel_z',
    'right_gyro_x',
    'right_gyro_y',
    'right_gyro_z',
    'right_mag_x',
    'right_mag_y',
    'right_mag_z',
    
    # Activity label
    'activity'
]
df = load_zipped_csv_dir('MHEALTHDATASET.zip', prefix='mHealth_subject', include_file_column=True, header=None, names=columns)

# %%
df
# Out:
#         chest_accel_x  chest_accel_y  chest_accel_z     ecg_1     ecg_2  \
# 0             -9.8184       0.009971       0.295630  0.004186  0.004186
# 1             -9.8489       0.524040       0.373480  0.004186  0.016745
# 2             -9.6602       0.181850       0.437420  0.016745  0.037677
# 3             -9.6507       0.214220       0.240330  0.079540  0.117220
# 4             -9.7030       0.303890       0.311560  0.221870  0.205130
# ...               ...            ...            ...       ...       ...
# 135163       -12.2440      -2.970600      -0.035772  0.812140  1.096800
# 135164       -10.9220      -3.419000      -0.339280  1.469400  1.285200
# 135165        -9.4842      -3.064300      -1.033700  0.238620  0.891680
# 135166        -8.7889      -2.475700      -0.612290 -0.205130  0.460490
# 135167        -8.6851      -1.098500       0.153770  0.318160  0.908420
#
#         left_accel_x  left_accel_y  left_accel_z  left_gyro_x  left_gyro_y  \
# ...
